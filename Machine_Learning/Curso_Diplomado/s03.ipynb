# %% [markdown]
# <p><img alt="Colaboratory logo" height="140px" src="https://upload.wikimedia.org/wikipedia/commons/archive/f/fb/20161010213812%21Escudo-UdeA.svg" align="left" hspace="10px" vspace="0px"></p>
#
# <h1> Diplomado de Análisis de datos y Machine Learning en Python</h1>
#
#
# El presente diplomado hace parte del centro de Big Data de la facultad de ciencias exactas y naturales (FCEN) de la Universidad de Antioquia.

# %% [markdown]
# <p><a name="contents"></a></p>
#
# # Contenido Sesión 3
#
# - <a href="#taller">1. Taller</a><br>
# - <a href="#manipulacionDatos">2. Manipulación de datos</a><br>
#  - <a href="#formateo">2.1 Formateo de datos temporales</a><br>
#  - <a href="#procesamientoNulos">2.2 Procesamiento de datos nulos</a><br>
#  - <a href="#indexacion">2.3. Indexación y localización</a><br>
#  - <a href="#organizacionDF">2.4. Organización de dataframes</a><br>
#  - <a href="#graficasPandas">2.5. Graficando desde pandas</a><br>
#  - <a href="#operacionesColFil">2.6. Operaciones con columnas y filas</a><br>
#   - <a href="#agrupacion"> 2.7. Agrupando dataframes</a><br>
#   - <a href="#renormalizacion">2.8. Renormalización de datos</a><br>
#   - <a href="#bineado"> 2.9. Bineado de datos</a><br>
#   - <a href="#concom"> 2.10. Concatenación y combinación de dataframes</a><br>
# - <a href="#tallpan">3. Taller Pandas</a><br>

# %% [markdown]
# <p><a name="taller"></a></p>
#
# # 1. Taller

# %% [markdown]
# ## Pregunta 1
#
# Definir una función max_de_dos(), que tome dos números como argumentos y devuelva el mayor de ellos. Si los números son iguales que imprima en pantalla "Los números son iguales" y no regrese ningún valor.

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
# def max_de_dos(a, b):
#
#
#   if a>b:
#     output=a
#   elif b>a:
#     output=b
#   else:
#     print('Los números son iguales')
#     output=None
#   return output
#
#
# -->

# %% [markdown]
# ## Pregunta 2
#
# Escriba un código de python que imprima todos los números pares de una lista dada y que deje de mostrar números cuando se encuentre el número 237
#
# Lista de números de muestra:
#
# numbers = [
# 386, 462, 47, 418, 907, 344, 236, 375, 823, 566, 597, 978, 328, 615, 953, 345, 399, 162, 758, 219, 918, 237, 412, 566, 826, 248, 866, 950, 626, 949, 687, 217, 815, 67, 104, 58, 512, 24, 892, 894, 767, 553, 81, 379, 843, 831, 445, 742, 717, 958,743, 527 ]

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
# numbers = [
# 386, 462, 47, 418, 907, 344, 236, 375, 823, 566, 597, 978, 328, 615, 953, 345, 399, 162, 758, 219, 918, 237, 412, 566, 826, 248, 866, 950, 626, 949, 687, 217, 815, 67, 104, 58, 512, 24, 892, 894, 767, 553, 81, 379, 843, 831, 445, 742, 717, 958,743, 527 ]
#
# listaFin=[]
# for i in numbers:
#   if (i%2==0):
#       listaFin.append(i)
#   if (i==237):
#       break
# print(listaFin)
#
# -->

# %% [markdown]
# ## Pregunta 3
#
#   * Mostrar con un while los números del 1 al 20
#
#   * Mostrar con un for los números del 1 al 20

# %%
# Escriba aquí su código

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
# a=1
# while a<=20:
#   print(a)
#   a+=1
#
# #####
#
# for a in range(1,21):
#   print(a)
#
# -->

# %% [markdown]
# ## Pregunta 4
#
# Juguemos al juego de adivinar el numero, generaremos un número entre 1 y 20.
#
# Nuestro objetivo es adivinar el número. Si fallamos nos dirán si es mayor o menor que el número buscado. También poner el número de intentos requeridos.

# %%
# Escriba aquí su código

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
# def adivina_numero():
#
#   import numpy as np
#   numero_buscado = np.random.randint(1, 21)
#
#   encontrado = False
#   intentos = 0
#
#   while not encontrado:
#
#       numero_usuario = int(input("Introduce el número buscado: "))
#
#       if numero_usuario > numero_buscado:
#           print("El número que buscas es menor")
#           intentos = intentos +1
#       elif numero_usuario < numero_buscado:
#           print("El numero que buscas es mayor")
#           intentos = intentos +1
#       else:
#           encontrado = True
#           print("Has acertado el número correcto es " , numero_usuario, " te ha llevado ", intentos," intentos")
#
# -->

# %% [markdown]
# ## Pregunta 5
#
# Defina una función llamada `es_cadena_no_vacia()` que evalúe si una cadena de caracteres es vacía o no y que retorne un variable booleana según sea el caso

# %%
# Escriba aquí su código

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
#
#         def es_cadena_no_vacia(cadena=None):
#           if cadena==None:
#             salida=False
#           else:
#             salida=True
#           return salida
#
# -->

# %% [markdown]
# ## Pregunta 6
#
# Defina una función llamada `es_numero()` que evalúa si la entrada es un número y que retorne una variable booleana según sea el caso

# %%
# Escriba aquí su código

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
# def es_numero(num=None):
#   if type(num)==int or type(num)==float:
#     salida=True
#   else:
#     salida=False
#
#   return salida
#
# -->

# %% [markdown]
# ## Pregunta 7
#
# Defina una clase llamada Hotel que contenga los atributos nombre, ubicación, puntaje obtenido por votación, y precio. Se tienen las siguientes restricciones:
#
# * El nombre y la ubicación deben ser cadenas no vacías.
# * El puntaje debe ser un número (sin restricciones sobre su valor)
# * El precio debe ser un número distinto de cero.
#
# si no se cumple alguna de las condiciones, ejecute un error que muestre en pantalla el problema.
#
# *Pista*: Use las funciónes `es_cadena_no_vacia()` y `es_numero()`

# %%
# Escriba aquí su código

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
# class Hotel(object):
#     """ Hotel: sus atributos son: nombre, ubicacion, puntaje y precio."""
#
#     def __init__(self, nombre = '*', ubicacion = '*',
#                  puntaje = 0, precio = float("inf")):
#         """ nombre y ubicacion deben ser cadenas no vacías,
#             puntaje y precio son números.
#             Si el precio es 0 se reemplaza por infinito. """
#
#         def es_cadena_no_vacia(cadena=None):
#           if cadena==None:
#             salida=False
#           else:
#             salida=True
#           return salida
#
#         def es_numero(num=None):
#           if type(num)==int or type(num)==float:
#             salida=True
#           else:
#             salida=False
#
#           return salida
#
#         if es_cadena_no_vacia (nombre):
#             self.nombre = nombre
#         else:
#             raise TypeError ("El nombre debe ser una cadena no vacía")
#
#         if es_cadena_no_vacia (ubicacion):
#             self.ubicacion = ubicacion
#         else:
#             raise TypeError ("La ubicación debe ser una cadena no vacía")
#
#         if es_numero(puntaje):
#             self.puntaje = puntaje
#         else:
#             raise TypeError ("El puntaje debe ser un número")
#
#         if es_numero(precio):
#             if precio != 0:
#                 self.precio = precio
#             else:
#                 self.precio = float("inf")
#         else:
#             raise TypeError("El precio debe ser un número")
#
#     def __str__(self):
#         """ Muestra el hotel según lo requerido. """
#         return self.nombre + " de "+ self.ubicacion+ \
#                 " - Puntaje: "+ str(self.puntaje) + " - Precio: "+ \
#                 str(self.precio)+ " pesos."
# -->

# %% [markdown]
# <p><a name="manipulacionDatos"></a></p>
#
# # 2. Manipulación de datos

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("https://raw.githubusercontent.com/diplomado-bigdata-machinelearning-udea/Curso1/master/s03/dataVentas2009.csv")

# %%
np.nan
# Out:
# nan

# %%
df.head(10)
# Out:
#         Fecha  Producto1  Producto2  Producto3  Producto4
# 0  01/01/2009         29         20         35        NaN
# 1  02/01/2009         19          3         22        NaN
# 2  03/01/2009         24         12         22        NaN
# 3  04/01/2009         24          8         15        NaN
# 4  05/01/2009        120        111        141        NaN
# 5  06/01/2009        261        146        236        NaN
# 6  07/01/2009         60         33         80        NaN
# 7  08/01/2009         24         14         14        NaN
# 8  09/01/2009         35         20         32        NaN
# 9  10/01/2009         81         45         79        NaN

# %%
df.columns
# Out:
# Index(['Fecha', 'Producto1', 'Producto2', 'Producto3', 'Producto4'], dtype='object')

# %%
df.shape
# Out:
# (365, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      365 non-null    object
#  1   Producto1  365 non-null    int64
#  2   Producto2  365 non-null    int64
#  3   Producto3  365 non-null    int64
#  4   Producto4  178 non-null    float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 14.4+ KB

# %%
l=df["Producto4"].unique()
l
# Out:
# array([  nan, 2156., 4548., 7575., 7268., 2320., 5081., 4236., 3755.,
#        6939., 4278., 5999., 3586., 4132., 7064., 6996., 4331., 6134.,
#        4639., 4635., 2144., 5041., 7219., 7208., 5237., 5869., 1753.,
#        7194., 5384., 7121., 5259., 5103., 5514., 3524., 4187., 4359.,
#        7127., 6971., 6178., 5078., 4416., 5683., 5647., 6901., 4902.,
#        3752., 4822., 4015., 5534., 7044., 6242., 6239., 5661., 1445.,
#        3064., 5941., 7052., 6864., 5837., 4185., 4036., 4375., 6763.,
#        6686., 6520., 6044., 5205., 3959., 4263., 4379., 4256., 3985.,
#        2169., 2550., 2605., 3599., 1923., 2044., 3183., 2709., 2547.,
#         656., 1415., 1342., 1799., 1588., 1906.,  705., 1116., 1773.,
#        2211.,  984., 1967.,  663., 1003.,  825.,  924.,  870., 1373.,
#        1311., 1238.,  919., 1006., 1483., 1374., 1442.,  633.,  952.,
#         286.,  833., 1191., 1114., 1075., 1230.,  958.,  309.,  859.,
#        1208.,  798., 1046.,  906.,  864.,  552., 1063., 1341., 1300.,
#        1175., 1108., 1005.,  321.,  404.,    0.])

# %%
df['Fecha']
# Out:
# 0      01/01/2009
# 1      02/01/2009
# 2      03/01/2009
# 3      04/01/2009
# 4      05/01/2009
#           ...
# 360    27/12/2009
# 361    28/12/2009
# 362    29/12/2009
# 363    30/12/2009
# 364    31/12/2009
# Name: Fecha, Length: 365, dtype: object

# %%
df.Fecha
# Out:
# 0      01/01/2009
# 1      02/01/2009
# 2      03/01/2009
# 3      04/01/2009
# 4      05/01/2009
#           ...
# 360    27/12/2009
# 361    28/12/2009
# 362    29/12/2009
# 363    30/12/2009
# 364    31/12/2009
# Name: Fecha, Length: 365, dtype: object

# %% [markdown]
# <p><a name="formateo"></a></p>
#
# ## 2.1. Formateo de datos temporales

# %% [markdown]
# La función `to_datetime` permite convertir los datos a un formato especial de tiempo

# %%
pd.to_datetime(df.Fecha)
# Out:
# 0     2009-01-01
# 1     2009-02-01
# 2     2009-03-01
# 3     2009-04-01
# 4     2009-05-01
#          ...
# 360   2009-12-27
# 361   2009-12-28
# 362   2009-12-29
# 363   2009-12-30
# 364   2009-12-31
# Name: Fecha, Length: 365, dtype: datetime64[ns]

# %%
df['Fecha'] = pd.to_datetime(df.Fecha, format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      365 non-null    datetime64[ns]
#  1   Producto1  365 non-null    int64
#  2   Producto2  365 non-null    int64
#  3   Producto3  365 non-null    int64
#  4   Producto4  178 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 14.4 KB

# %%
#df.Fecha=pd.to_datetime(df.Fecha)
df.set_index('Fecha', inplace=True)
df.head()
# Out:
#             Producto1  Producto2  Producto3  Producto4
# Fecha
# 2009-01-01         29         20         35        NaN
# 2009-01-02         19          3         22        NaN
# 2009-01-03         24         12         22        NaN
# 2009-01-04         24          8         15        NaN
# 2009-01-05        120        111        141        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2009-01-01 to 2009-12-31
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Producto1  365 non-null    int64
#  1   Producto2  365 non-null    int64
#  2   Producto3  365 non-null    int64
#  3   Producto4  178 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 14.3 KB

# %% [markdown]
# <p><a name="procesamientoNulos"></a></p>
#
# ## 2.2. Procesamiento de datos nulos

# %%
df
# Out:
#             Producto1  Producto2  Producto3  Producto4
# Fecha
# 2009-01-01         29         20         35        NaN
# 2009-01-02         19          3         22        NaN
# 2009-01-03         24         12         22        NaN
# 2009-01-04         24          8         15        NaN
# 2009-01-05        120        111        141        NaN
# ...               ...        ...        ...        ...
# 2009-12-27         66         29         52        0.0
# 2009-12-28         61         41         99        0.0
# 2009-12-29         89         52        115        0.0
# 2009-12-30         76         43        115        0.0
# 2009-12-31         53         46        112        0.0
#
# [365 rows x 4 columns]

# %%
df.isna().head()
# Out:
#             Producto1  Producto2  Producto3  Producto4
# Fecha
# 2009-01-01      False      False      False       True
# 2009-01-02      False      False      False       True
# 2009-01-03      False      False      False       True
# 2009-01-04      False      False      False       True
# 2009-01-05      False      False      False       True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2009-01-01 to 2009-12-31
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Producto1  365 non-null    int64
#  1   Producto2  365 non-null    int64
#  2   Producto3  365 non-null    int64
#  3   Producto4  178 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 14.3 KB

# %%
df.isnull().sum()
# Out:
# Producto1      0
# Producto2      0
# Producto3      0
# Producto4    187
# dtype: int64

# %% [markdown]
#  Es lo mismo que df.isnull, ver: https://datascience.stackexchange.com/questions/37878/difference-between-isna-and-isnull-in-pandas

# %% [markdown]
# Usar el comando `fillna()` para reemplazar los valores nulos con el valor deseado. Puede hacerse en una sola columna `df.columna.fillna()` o en todas al mismo tiempo `df.fillna()`

# %%
# Solo visual
df.Producto4.fillna(0)
# Out:
# Fecha
# 2009-01-01    0.0
# 2009-01-02    0.0
# 2009-01-03    0.0
# 2009-01-04    0.0
# 2009-01-05    0.0
#              ...
# 2009-12-27    0.0
# 2009-12-28    0.0
# 2009-12-29    0.0
# 2009-12-30    0.0
# 2009-12-31    0.0
# Name: Producto4, Length: 365, dtype: float64

# %%
df
# Out:
#             Producto1  Producto2  Producto3  Producto4
# Fecha
# 2009-01-01         29         20         35        NaN
# 2009-01-02         19          3         22        NaN
# 2009-01-03         24         12         22        NaN
# 2009-01-04         24          8         15        NaN
# 2009-01-05        120        111        141        NaN
# ...               ...        ...        ...        ...
# 2009-12-27         66         29         52        0.0
# 2009-12-28         61         41         99        0.0
# 2009-12-29         89         52        115        0.0
# 2009-12-30         76         43        115        0.0
# 2009-12-31         53         46        112        0.0
#
# [365 rows x 4 columns]

# %%
df.describe()
# Out:
#          Producto1    Producto2    Producto3    Producto4
# count   365.000000   365.000000   365.000000   178.000000
# mean   2032.200000  1060.252055  2093.169863  2576.359551
# std    1878.879799  1079.533086  1854.368523  2484.004743
# min       0.000000     0.000000     0.000000     0.000000
# 25%     194.000000    90.000000   228.000000     0.000000
# 50%    1726.000000   678.000000  1686.000000  1443.500000
# 75%    3540.000000  1882.000000  3520.000000  4638.000000
# max    6626.000000  4242.000000  6587.000000  7575.000000

# %%
# Cambiando los datos
df.Producto4.fillna(df.Producto4.mean(),inplace=True) #Importante inplace
df
# Out:
#             Producto1  Producto2  Producto3    Producto4
# Fecha
# 2009-01-01         29         20         35  2576.359551
# 2009-01-02         19          3         22  2576.359551
# 2009-01-03         24         12         22  2576.359551
# 2009-01-04         24          8         15  2576.359551
# 2009-01-05        120        111        141  2576.359551
# ...               ...        ...        ...          ...
# 2009-12-27         66         29         52     0.000000
# 2009-12-28         61         41         99     0.000000
# 2009-12-29         89         52        115     0.000000
# 2009-12-30         76         43        115     0.000000
# 2009-12-31         53         46        112     0.000000
#
# [365 rows x 4 columns]

# %%
df.describe()
# Out:
#          Producto1    Producto2    Producto3    Producto4
# count   365.000000   365.000000   365.000000   365.000000
# mean   2032.200000  1060.252055  2093.169863  2576.359551
# std    1878.879799  1079.533086  1854.368523  1732.161423
# min       0.000000     0.000000     0.000000     0.000000
# 25%     194.000000    90.000000   228.000000  1588.000000
# 50%    1726.000000   678.000000  1686.000000  2576.359551
# 75%    3540.000000  1882.000000  3520.000000  2576.359551
# max    6626.000000  4242.000000  6587.000000  7575.000000

# %%
r=np.array(df['Producto4'])
r

# %% [markdown]
# <p><a name="indexacion"></a></p>
#
# ## 2.3. Indexación y localización
# Usando los comandos `iloc` y `loc`  en un dataframe, se puede acceder a los datos con base en las etiquetas y la ubicación respectivamente

# %%
df.iloc[100:110:2]
# Out:
#             Producto1  Producto2  Producto3    Producto4
# Fecha
# 2009-04-11          0          0          0  2576.359551
# 2009-04-13          0          0          0  2576.359551
# 2009-04-15          0          0          0  2576.359551
# 2009-04-17       1286        820       1436  2576.359551
# 2009-04-19       2131       1155       1426  2576.359551

# %% [markdown]
# Indexación para un subconjunto de columnas

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Fecha'>

# %%
df[['Producto1','Producto4']].iloc[100:110]
# Out:
#             Producto1    Producto4
# Fecha
# 2009-04-11          0  2576.359551
# 2009-04-12          0  2576.359551
# 2009-04-13          0  2576.359551
# 2009-04-14          0  2576.359551
# 2009-04-15          0  2576.359551
# 2009-04-16          0  2576.359551
# 2009-04-17       1286  2576.359551
# 2009-04-18       1178  2576.359551
# 2009-04-19       2131  2576.359551
# 2009-04-20       2709  2576.359551

# %%
df.iloc[::-1,1:3:1]
# Out:
#             Producto2  Producto3
# Fecha
# 2009-12-31         46        112
# 2009-12-30         43        115
# 2009-12-29         52        115
# 2009-12-28         41         99
# 2009-12-27         29         52
# ...               ...        ...
# 2009-01-05        111        141
# 2009-01-04          8         15
# 2009-01-03         12         22
# 2009-01-02          3         22
# 2009-01-01         20         35
#
# [365 rows x 2 columns]

# %%
df.loc["2009-10-01":"2009-10-10"]
# Out:
#             Producto1  Producto2  Producto3  Producto4
# Fecha
# 2009-10-01       2643         22       3528     1588.0
# 2009-10-02       2865         36       3735     1906.0
# 2009-10-03        993          7       1362      705.0
# 2009-10-04       1336          0       1620     1116.0
# 2009-10-05       2935        308       3801     1773.0
# 2009-10-06       3852          7       4610     2211.0
# 2009-10-07       2115          3       2825      984.0
# 2009-10-08       3336          9       4146     1967.0
# 2009-10-09       1302        482       1686      663.0
# 2009-10-10       1407        725       1443     1003.0

# %% [markdown]
# Parar reasignar un valor de dataframe, simplemente se debe saber la localización, ya sea por indice o por etiqueta y usar el operador de asignación `=`

# %%
df.iloc[109,0]
# Out:
# 2709

# %%
df.iloc[109,0]=1000

# %%
df.loc['2009-04-19','Producto1']=998

# %%
df.loc['2009-04-19','Producto1']
# Out:
# 998.0

# %%
df.index
# Out:
# DatetimeIndex(['2009-01-01', '2009-01-02', '2009-01-03', '2009-01-04',
#                '2009-01-05', '2009-01-06', '2009-01-07', '2009-01-08',
#                '2009-01-09', '2009-01-10',
#                ...
#                '2009-12-22', '2009-12-23', '2009-12-24', '2009-12-25',
#                '2009-12-26', '2009-12-27', '2009-12-28', '2009-12-29',
#                '2009-12-30', '2009-12-31'],
#               dtype='datetime64[ns]', name='Fecha', length=365, freq=None)

# %%
df.head()
# Out:
#             Producto1  Producto2  Producto3    Producto4
# Fecha
# 2009-01-01         29         20         35  2576.359551
# 2009-01-02         19          3         22  2576.359551
# 2009-01-03         24         12         22  2576.359551
# 2009-01-04         24          8         15  2576.359551
# 2009-01-05        120        111        141  2576.359551

# %% [markdown]
# Validemos la re-asignación de los valores

# %%
df.iloc[108:110, 0 :1]
#df.iloc[111:113, 0:1]
# Out:
#             Producto1
# Fecha
# 2009-04-19        998
# 2009-04-20       1000

# %%
df.iloc[108:110, 0 :1]
# Out:
#             Producto1
# Fecha
# 2009-04-19        998
# 2009-04-20       1000

# %% [markdown]
# <p><a name="organizacionDF"></a></p>
#
# ## 2.4. Organización de dataframes
# El método `sort_values` permite organizar los dataframes con base a los valores de las columnas o las filas

# %%
df.sort_values(by=["Producto1", "Producto2"],ascending=False)
# Out:
#             Producto1  Producto2  Producto3    Producto4
# Fecha
# 2009-07-09       6626       4227       5751  7575.000000
# 2009-06-17       6320       3388       6047  2576.359551
# 2009-07-10       6274       4242       5435  7268.000000
# 2009-07-15       6100       3767       5536  6939.000000
# 2009-06-05       6028       4120       4223  2576.359551
# ...               ...        ...        ...          ...
# 2009-04-12          0          0          0  2576.359551
# 2009-04-13          0          0          0  2576.359551
# 2009-04-14          0          0          0  2576.359551
# 2009-04-15          0          0          0  2576.359551
# 2009-04-16          0          0          0  2576.359551
#
# [365 rows x 4 columns]

# %%
df
# Out:
#             Producto1  Producto2  Producto3    Producto4
# Fecha
# 2009-01-01         29         20         35  2576.359551
# 2009-01-02         19          3         22  2576.359551
# 2009-01-03         24         12         22  2576.359551
# 2009-01-04         24          8         15  2576.359551
# 2009-01-05        120        111        141  2576.359551
# ...               ...        ...        ...          ...
# 2009-12-27         66         29         52     0.000000
# 2009-12-28         61         41         99     0.000000
# 2009-12-29         89         52        115     0.000000
# 2009-12-30         76         43        115     0.000000
# 2009-12-31         53         46        112     0.000000
#
# [365 rows x 4 columns]

# %%
help(df.sort_values)

# %% [markdown]
# <p><a name="graficasPandas"></a></p>
#
# ## 2.5. Graficando desde pandas
# Pandas permite realizar algunas gráficas directamente con el comando `DataFrame.plot()`.

# %%
df.plot(y='Producto2',x='Producto1',kind='scatter',)
# Out:
# <AxesSubplot:xlabel='Producto1', ylabel='Producto2'>

# %%
import matplotlib.pyplot as plt

df.plot(figsize=(15,3),)
plt.ylabel("Cantidad de productos")
plt.title('Titulp')
plt.show()

# %%
help(df.plot)

# %% [markdown]
# Además de gráficos de línea, pandas tiene otro tipo de gráficos los cuales se puede usar con el argumento `kind` dentro del método DataFrame.plot(). Los otro gráficos disponibles son:
#
# * `'bar'` or `'barh'` for bar plots
# * `'hist'` for histogram
# * `'box'` for boxplot
# * `'kde'` or `'density'` for density plots
# * ‘`'area'` for area plots
# * `'scatter'` for scatter plots
# * `'hexbin'` for hexagonal bin plots
# * `'pie'` for pie plots

# %%
import matplotlib.pyplot as plt
df.Producto1.plot(kind='hist', grid=True, bins=8)

plt.xlabel('Numero de productos')
plt.show()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
a=np.array([1,1,1,1,1,1,1])

# %%
import math

# %%
math.cos(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-60ba4a8164bc> in <module>
# ----> 1 math.cos(a)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %% [markdown]
# <p><a name="operacionesColFil"></a></p>
#
# ## 2.6. Operaciones con columnas y filas
# La función `apply` regresa algún valor después de aplicarle una función a cada columna/fila del dataframe.

# %%
df['Producto3sqrt']=df.Producto3.apply(np.mean)

# %%
df.tail()
# Out:
#             Producto1  Producto2  Producto3  Producto4  Producto3sqrt
# Fecha
# 2009-12-27         66         29         52        0.0           52.0
# 2009-12-28         61         41         99        0.0           99.0
# 2009-12-29         89         52        115        0.0          115.0
# 2009-12-30         76         43        115        0.0          115.0
# 2009-12-31         53         46        112        0.0          112.0

# %%
df['Total']=df['Producto1']+df['Producto2']+df['Producto3']

# %%
df.head()
# Out:
#             Producto1  Producto2  Producto3    Producto4  Producto3sqrt  Total
# Fecha
# 2009-01-01         29         20         35  2576.359551           35.0     84
# 2009-01-02         19          3         22  2576.359551           22.0     44
# 2009-01-03         24         12         22  2576.359551           22.0     58
# 2009-01-04         24          8         15  2576.359551           15.0     47
# 2009-01-05        120        111        141  2576.359551          141.0    372

# %%
a =df.apply(np.sum, axis=1)
a
# Out:
# Fecha
# 2009-01-01    2779.359551
# 2009-01-02    2686.359551
# 2009-01-03    2714.359551
# 2009-01-04    2685.359551
# 2009-01-05    3461.359551
#                  ...
# 2009-12-27     346.000000
# 2009-12-28     501.000000
# 2009-12-29     627.000000
# 2009-12-30     583.000000
# 2009-12-31     534.000000
# Length: 365, dtype: float64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df.apply(np.sum, axis=0).plot(kind='pie',)
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2009-01-01 to 2009-12-31
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Producto1      365 non-null    int64
#  1   Producto2      365 non-null    int64
#  2   Producto3      365 non-null    int64
#  3   Producto4      365 non-null    float64
#  4   Producto3sqrt  365 non-null    float64
#  5   Total          365 non-null    int64
# dtypes: float64(2), int64(4)
# memory usage: 28.1 KB

# %% [markdown]
# <p><a name="agrupacion"></a></p>
#
# ## 2.7. Agrupando dataframes
# El comando `groupby` permite agrupar y generar calculos y operaciónes sobre los valores agrupados.

# %%
df["month"] = [i.month for i in df.index]
df.head(20)
# Out:
#             Producto1  Producto2  Producto3    Producto4  Producto3sqrt  \
# Fecha
# 2009-01-01         29         20         35  2576.359551           35.0
# 2009-01-02         19          3         22  2576.359551           22.0
# 2009-01-03         24         12         22  2576.359551           22.0
# 2009-01-04         24          8         15  2576.359551           15.0
# 2009-01-05        120        111        141  2576.359551          141.0
# 2009-01-06        261        146        236  2576.359551          236.0
# 2009-01-07         60         33         80  2576.359551           80.0
# 2009-01-08         24         14         14  2576.359551           14.0
# 2009-01-09         35         20         32  2576.359551           32.0
# 2009-01-10         81         45         79  2576.359551           79.0
# 2009-01-11        318        160        306  2576.359551          306.0
# 2009-01-12        105         99        170  2576.359551          170.0
# 2009-01-13        168         94        172  2576.359551          172.0
# 2009-01-14        145         87        175  2576.359551          175.0
# 2009-01-15        131         90        172  2576.359551          172.0
# 2009-01-16         93         49         97  2576.359551           97.0
# 2009-01-17         25         13         20  2576.359551           20.0
# 2009-01-18         52         22         55  2576.359551           55.0
# 2009-01-19        136        127        202  2576.359551          202.0
# 2009-01-20        147         85        176  2576.359551          176.0
#
#             Total  month
# Fecha
# 2009-01-01     84      1
# 2009-01-02     44      1
# 2009-01-03     58      1
# 2009-01-04     47      1
# 2009-01-05    372      1
# 2009-01-06    643      1
# 2009-01-07    173      1
# 2009-01-08     52      1
# 2009-01-09     87      1
# 2009-01-10    205      1
# 2009-01-11    784      1
# 2009-01-12    374      1
# 2009-01-13    434      1
# 2009-01-14    407      1
# 2009-01-15    393      1
# 2009-01-16    239      1
# 2009-01-17     58      1
# 2009-01-18    129      1
# 2009-01-19    465      1
# 2009-01-20    408      1

# %%
df.head()
# Out:
#             Producto1  Producto2  Producto3  ...  Producto3sqrt  Total  month
# Fecha                                        ...
# 2009-01-01         29         20         35  ...       5.916080     84      1
# 2009-01-02         19          3         22  ...       4.690416     44      1
# 2009-01-03         24         12         22  ...       4.690416     58      1
# 2009-01-04         24          8         15  ...       3.872983     47      1
# 2009-01-05        120        111        141  ...      11.874342    372      1
#
# [5 rows x 7 columns]

# %%
df.groupby("month").max()
# Out:
#        Producto1  Producto2  Producto3    Producto4  Producto3sqrt  Total
# month
# 1            318        160        306  2576.359551      17.492856    784
# 2            326        176        371  2576.359551      19.261360    873
# 3            871        484        967  2576.359551      31.096624   2322
# 4           4051       2534       3924  2576.359551      62.641839  10509
# 5           5728       3693       5397  2576.359551      73.464277  14818
# 6           6320       4120       6047  2576.359551      77.762459  15755
# 7           6626       4242       5751  7575.000000      75.835348  16604
# 8           5904       3102       5698  7194.000000      75.485098  13859
# 9           5575       2921       6587  7052.000000      81.160335  15004
# 10          3852       1478       4610  2211.000000      67.896981   8469
# 11          2540       1270       3430  1341.000000      58.566202   7226
# 12          1377        711       1867     0.000000      43.208795   3955

# %%
df.groupby("month")["Producto1"].sum().plot(kind='bar')
#plt.ylabel("Total por mes")
#plt.title("")

# %%
df2 = pd.DataFrame({"Person": ["John", "Myla", "Lewis", "John", "Myla", "Lewis", "John", "Myla"], "Age": [24, 55, 21, 24, 26, 43, 64, 55]})
df2.head(8)
# Out:
#   Person  Age
# 0   John   24
# 1   Myla   55
# 2  Lewis   21
# 3   John   24
# 4   Myla   26
# 5  Lewis   43
# 6   John   64
# 7   Myla   55

# %%
# Agrupar por persona y aplicar "min" a "Age"
#df2.groupby("Person")['Age'].agg("min")             
df2.groupby("Person").Age.agg('min')
# Out:
# Person
# John     24
# Lewis    21
# Myla     26
# Name: Age, dtype: int64

# %%
# Agrupar por persona y edad y aplicar "count" a "Age"
df2.groupby(["Person","Age"]).agg({"Person":"max"})
# Out:
#            Person
# Person Age
# John   24    John
#        64    John
# Lewis  21   Lewis
#        43   Lewis
# Myla   26    Myla
#        55    Myla

# %%
# frecuencia de las edades
a = df2['Age'].value_counts()
#df2["Age"].value_counts(Normlize=True)
# Out:
# 55    2
# 24    2
# 21    1
# 43    1
# 26    1
# Name: Age, dtype: int64

# %% [markdown]
# <p><a name="renormalizacion"></a></p>
#
# ## 2.8. Normalización de datos
# En algunos algoritmos de Machine Learning (ML) es importante tener los datos normalizados. Para ellos la función `scale` se encarga de normalizar los datos quedando con una media cercana a 0 y una desviación estandar de 1

# %%
# %pip install sklearn
from sklearn import preprocessing

# %%
scaled=preprocessing.scale(df[['Producto4', 'Producto3sqrt']])

# %%
scaled
# Out:
# array([[-2.62892112e-16, -1.11142691e+00],
#        [-2.62892112e-16, -1.11844701e+00],
#        [-2.62892112e-16, -1.11844701e+00],
#        [-2.62892112e-16, -1.12222706e+00],
#        [-2.62892112e-16, -1.05418613e+00],
#        [-2.62892112e-16, -1.00288543e+00],
#        [-2.62892112e-16, -1.08712658e+00],
#        [-2.62892112e-16, -1.12276707e+00],
#        [-2.62892112e-16, -1.11304693e+00],
#        [-2.62892112e-16, -1.08766659e+00],
#        [-2.62892112e-16, -9.65084912e-01],
#        [-2.62892112e-16, -1.03852592e+00],
#        [-2.62892112e-16, -1.03744590e+00],
#        [-2.62892112e-16, -1.03582588e+00],
#        [-2.62892112e-16, -1.03744590e+00],
#        [-2.62892112e-16, -1.07794645e+00],
#        [-2.62892112e-16, -1.11952702e+00],
#        [-2.62892112e-16, -1.10062676e+00],
#        [-2.62892112e-16, -1.02124568e+00],
#        [-2.62892112e-16, -1.03528587e+00],
#        [-2.62892112e-16, -1.05634616e+00],
#        [-2.62892112e-16, -1.01962566e+00],
#        [-2.62892112e-16, -1.04770604e+00],
#        [-2.62892112e-16, -1.12492710e+00],
#        [-2.62892112e-16, -1.11520696e+00],
#        [-2.62892112e-16, -1.05688617e+00],
#        [-2.62892112e-16, -1.01098554e+00],
#        [-2.62892112e-16, -1.06930634e+00],
#        [-2.62892112e-16, -1.06714631e+00],
#        [-2.62892112e-16, -1.07308639e+00],
#        [-2.62892112e-16, -1.11952702e+00],
#        [-2.62892112e-16, -1.12924715e+00],
#        [-2.62892112e-16, -1.03636589e+00],
#        [-2.62892112e-16, -1.04986607e+00],
#        [-2.62892112e-16, -1.04986607e+00],
#        [-2.62892112e-16, -1.09144664e+00],
#        [-2.62892112e-16, -1.02340571e+00],
#        [-2.62892112e-16, -1.09090663e+00],
#        [-2.62892112e-16, -1.08766659e+00],
#        [-2.62892112e-16, -1.02772577e+00],
#        [-2.62892112e-16, -9.89925251e-01],
#        [-2.62892112e-16, -9.66164927e-01],
#        [-2.62892112e-16, -1.00558547e+00],
#        [-2.62892112e-16, -1.01044553e+00],
#        [-2.62892112e-16, -1.08442654e+00],
#        [-2.62892112e-16, -1.07578642e+00],
#        [-2.62892112e-16, -9.73185023e-01],
#        [-2.62892112e-16, -9.42404602e-01],
#        [-2.62892112e-16, -9.29984432e-01],
#        [-2.62892112e-16, -1.03690589e+00],
#        [-2.62892112e-16, -1.04230597e+00],
#        [-2.62892112e-16, -1.09090663e+00],
#        [-2.62892112e-16, -1.09738672e+00],
#        [-2.62892112e-16, -1.06714631e+00],
#        [-2.62892112e-16, -1.06066622e+00],
#        [-2.62892112e-16, -1.04932606e+00],
#        [-2.62892112e-16, -9.61304860e-01],
#        [-2.62892112e-16, -1.04554601e+00],
#        [-2.62892112e-16, -1.12114704e+00],
#        [-2.62892112e-16, -1.08712658e+00],
#        [-2.62892112e-16, -1.08010648e+00],
#        [-2.62892112e-16, -1.02394572e+00],
#        [-2.62892112e-16, -1.04608602e+00],
#        [-2.62892112e-16, -9.26204381e-01],
#        [-2.62892112e-16, -1.02340571e+00],
#        [-2.62892112e-16, -1.02286570e+00],
#        [-2.62892112e-16, -1.00126541e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -9.39164558e-01],
#        [-2.62892112e-16, -9.73725030e-01],
#        [-2.62892112e-16, -1.04068594e+00],
#        [-2.62892112e-16, -1.03312584e+00],
#        [-2.62892112e-16, -9.81825141e-01],
#        [-2.62892112e-16, -9.00824034e-01],
#        [-2.62892112e-16, -8.31163082e-01],
#        [-2.62892112e-16, -6.08140035e-01],
#        [-2.62892112e-16, -8.52223370e-01],
#        [-2.62892112e-16, -8.84623813e-01],
#        [-2.62892112e-16, -8.09562787e-01],
#        [-2.62892112e-16, -8.90563894e-01],
#        [-2.62892112e-16, -9.65084912e-01],
#        [-2.62892112e-16, -1.00720549e+00],
#        [-2.62892112e-16, -9.17024255e-01],
#        [-2.62892112e-16, -9.64004897e-01],
#        [-2.62892112e-16, -8.95963968e-01],
#        [-2.62892112e-16, -9.44564632e-01],
#        [-2.62892112e-16, -1.05634616e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -8.88943872e-01],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -1.13032717e+00],
#        [-2.62892112e-16, -3.54876575e-01],
#        [-2.62892112e-16, -6.84281075e-01],
#        [-2.62892112e-16, -3.60276648e-01],
#        [-2.62892112e-16,  2.98532353e-01],
#        [-2.62892112e-16, -8.21442949e-01],
#        [-2.62892112e-16, -8.48728856e-02],
#        [-2.62892112e-16,  1.94310929e-01],
#        [-2.62892112e-16,  3.51453076e-01],
#        [-2.62892112e-16,  6.61957318e-01],
#        [-2.62892112e-16, -6.15160131e-01],
#        [-2.62892112e-16,  9.88661782e-01],
#        [-2.62892112e-16,  2.07811113e-01],
#        [-2.62892112e-16,  4.69714692e-01],
#        [-2.62892112e-16,  9.85421738e-01],
#        [-2.62892112e-16, -3.19776095e-01],
#        [-2.62892112e-16, -3.62436678e-01],
#        [-2.62892112e-16, -3.62976685e-01],
#        [-2.62892112e-16,  9.80021664e-01],
#        [-2.62892112e-16,  1.22788505e+00],
#        [-2.62892112e-16,  1.30590058e-01],
#        [-2.62892112e-16, -6.08680042e-01],
#        [-2.62892112e-16,  1.98090980e-01],
#        [-2.62892112e-16, -3.18156073e-01],
#        [-2.62892112e-16, -8.47903311e-01],
#        [-2.62892112e-16,  7.70498801e-01],
#        [-2.62892112e-16,  9.60581398e-01],
#        [-2.62892112e-16,  1.29214593e+00],
#        [-2.62892112e-16,  1.88370848e-01],
#        [-2.62892112e-16,  7.92639104e-01],
#        [-2.62892112e-16, -8.07942765e-01],
#        [-2.62892112e-16, -6.90221157e-01],
#        [-2.62892112e-16, -2.24734797e-01],
#        [-2.62892112e-16,  3.37952891e-01],
#        [-2.62892112e-16, -6.27325831e-02],
#        [-2.62892112e-16,  1.78409265e+00],
#        [-2.62892112e-16,  9.69761524e-01],
#        [-2.62892112e-16,  6.87337665e-01],
#        [-2.62892112e-16,  6.88417680e-01],
#        [-2.62892112e-16,  1.00054194e+00],
#        [-2.62892112e-16,  9.94601863e-01],
#        [-2.62892112e-16, -1.91254339e-01],
#        [-2.62892112e-16, -9.99930922e-02],
#        [-2.62892112e-16, -4.56937969e-01],
#        [-2.62892112e-16, -4.67198109e-01],
#        [-2.62892112e-16, -3.12215992e-01],
#        [-2.62892112e-16,  3.41732943e-01],
#        [-2.62892112e-16,  8.96320520e-01],
#        [-2.62892112e-16,  6.29556876e-01],
#        [-2.62892112e-16,  1.45900821e+00],
#        [-2.62892112e-16,  1.15012399e+00],
#        [-2.62892112e-16,  5.93376381e-01],
#        [-2.62892112e-16, -3.84576981e-01],
#        [-2.62892112e-16,  8.90380439e-01],
#        [-2.62892112e-16, -4.21837490e-01],
#        [-2.62892112e-16,  1.01782218e+00],
#        [-2.62892112e-16,  1.46278826e+00],
#        [-2.62892112e-16,  8.76880255e-01],
#        [-2.62892112e-16,  6.82477599e-01],
#        [-2.62892112e-16,  5.54495850e-01],
#        [-2.62892112e-16,  7.80218934e-01],
#        [-2.62892112e-16,  1.89857421e+00],
#        [-2.62892112e-16,  2.13509745e+00],
#        [-2.62892112e-16,  2.36431504e-01],
#        [-2.62892112e-16,  6.56557245e-01],
#        [-2.62892112e-16,  3.67653297e-01],
#        [-2.62892112e-16,  2.36431504e-01],
#        [-2.62892112e-16,  1.58698996e+00],
#        [-2.62892112e-16,  1.77815257e+00],
#        [-2.62892112e-16,  5.51255806e-01],
#        [-2.62892112e-16,  1.32184633e+00],
#        [-2.62892112e-16,  1.02106222e+00],
#        [-2.62892112e-16, -2.36614959e-01],
#        [-2.62892112e-16,  3.21752670e-01],
#        [-2.62892112e-16, -3.95917135e-01],
#        [-2.62892112e-16,  1.28458583e+00],
#        [-2.62892112e-16,  5.17235341e-01],
#        [-2.62892112e-16,  1.31320622e+00],
#        [-2.62892112e-16,  5.26955474e-01],
#        [-2.62892112e-16,  1.25189984e-01],
#        [-2.62892112e-16,  6.57097252e-01],
#        [-2.62892112e-16,  1.16416418e+00],
#        [-2.43012323e-01,  7.69418787e-01],
#        [ 1.13981691e+00,  9.68141502e-01],
#        [ 2.88974338e+00,  1.97525526e+00],
#        [ 2.71226488e+00,  1.80461293e+00],
#        [-1.48202961e-01, -8.05528266e-02],
#        [ 1.44794734e+00,  5.69616057e-01],
#        [ 9.59447884e-01,  9.80561671e-01],
#        [ 6.81378961e-01,  1.03996248e+00],
#        [ 2.52206805e+00,  1.85915368e+00],
#        [ 9.83728330e-01,  9.07660675e-01],
#        [ 1.97864853e+00,  1.20412473e+00],
#        [ 5.83679069e-01,  3.83853519e-01],
#        [ 8.99324874e-01,  3.33632832e-01],
#        [ 2.59433128e+00,  1.61939040e+00],
#        [ 2.55502008e+00,  1.76249235e+00],
#        [ 1.01436794e+00,  1.00486200e+00],
#        [ 2.05669282e+00,  1.48114851e+00],
#        [ 1.19242455e+00,  9.36821074e-01],
#        [ 1.19011213e+00,  5.21555400e-01],
#        [-2.49949594e-01, -2.10694605e-01],
#        [ 1.42482311e+00,  1.19548461e+00],
#        [ 2.68393769e+00,  1.80569295e+00],
#        [ 1.42482311e+00,  1.14364390e+00],
#        [ 2.67757853e+00,  1.66853107e+00],
#        [ 1.53813186e+00,  1.04212251e+00],
#        [ 1.90349477e+00,  6.79237554e-01],
#        [-4.75988988e-01, -4.32097630e-01],
#        [ 2.66948504e+00,  1.49032864e+00],
#        [ 1.62311342e+00,  1.21870493e+00],
#        [ 2.62728332e+00,  1.67825120e+00],
#        [ 1.55085019e+00,  1.19062454e+00],
#        [ 1.46066567e+00,  1.19332458e+00],
#        [ 1.69826718e+00,  5.97696440e-01],
#        [ 5.47836505e-01,  1.61910486e-01],
#        [ 9.31120696e-01,  5.89596330e-01],
#        [ 1.03055491e+00,  8.69320152e-01],
#        [ 2.63075195e+00,  1.62749051e+00],
#        [ 2.54056743e+00,  1.59995013e+00],
#        [ 2.08212948e+00,  1.38772723e+00],
#        [ 1.44621303e+00,  5.04275164e-01],
#        [ 1.06350694e+00,  4.04913806e-01],
#        [ 1.79596708e+00,  1.25758546e+00],
#        [ 1.77515526e+00,  1.36936698e+00],
#        [ 2.50010002e+00,  1.69445143e+00],
#        [ 1.34446639e+00,  9.68681509e-01],
#        [ 6.79644643e-01,  5.79336189e-01],
#        [ 1.29821792e+00,  5.49095776e-01],
#        [ 8.31686487e-01,  2.99072360e-01],
#        [ 1.70982930e+00,  1.33912657e+00],
#        [ 2.58276916e+00,  1.94663487e+00],
#        [ 2.11912826e+00,  1.63019055e+00],
#        [ 2.11739394e+00,  1.66205098e+00],
#        [ 1.78324875e+00,  1.39852738e+00],
#        [-6.54045596e-01, -4.65578087e-01],
#        [ 2.81907806e-01,  3.44687449e-02],
#        [ 1.94511839e+00,  1.55188948e+00],
#        [ 2.52206805e+00,  1.98281537e+00],
#        [ 2.58739401e+00,  1.84889354e+00],
#        [ 2.47871011e+00,  1.98119534e+00],
#        [ 1.88499538e+00,  1.74629213e+00],
#        [ 9.29964485e-01,  5.21555400e-01],
#        [ 8.43826710e-01,  3.78453445e-01],
#        [ 1.03980460e+00,  2.88812220e-01],
#        [ 2.42032141e+00,  2.31437990e+00],
#        [ 2.37580726e+00,  2.39862105e+00],
#        [ 2.27984169e+00,  2.42670143e+00],
#        [ 2.00466329e+00,  2.05301632e+00],
#        [ 1.51963247e+00,  9.61121406e-01],
#        [ 7.99312558e-01,  3.69273319e-01],
#        [ 9.75056742e-01,  1.59833011e+00],
#        [ 1.04211702e+00,  2.08703679e+00],
#        [ 9.71010001e-01,  2.18855818e+00],
#        [ 8.14343311e-01,  2.19017820e+00],
#        [-2.35496947e-01,  9.06580661e-01],
#        [-1.52386109e-02,  3.15272582e-01],
#        [ 1.65572119e-02,  3.71973356e-01],
#        [ 5.91194445e-01,  2.03195604e+00],
#        [-3.77710991e-01,  8.14779406e-01],
#        [-3.07760180e-01,  1.04590256e+00],
#        [ 3.50702404e-01,  2.07839667e+00],
#        [ 7.66802223e-02,  1.57942985e+00],
#        [-1.69729285e-02,  4.21114028e-01],
#        [-1.11017113e+00, -5.71419533e-01],
#        [-6.71388772e-01,  3.88173578e-01],
#        [-7.13590500e-01,  4.23814065e-01],
#        [-4.49396118e-01,  9.67061487e-01],
#        [-5.71376457e-01,  7.74818860e-01],
#        [-3.87538790e-01,  8.86600388e-01],
#        [-1.08184394e+00, -3.94837121e-01],
#        [-8.44242427e-01, -2.55515217e-01],
#        [-4.64426871e-01,  9.22240875e-01],
#        [-2.11216500e-01,  1.35910684e+00],
#        [-9.20552401e-01,  3.95193674e-01],
#        [-3.52274332e-01,  1.10854342e+00],
#        [-1.10612439e+00, -2.19874730e-01],
#        [-9.09568390e-01, -3.51096523e-01],
#        [-1.01247123e+00, -4.43977792e-01],
#        [-9.55238753e-01, -5.21738855e-01],
#        [-9.86456470e-01,  6.36291433e-02],
#        [-6.95669218e-01,  6.14976676e-01],
#        [-7.31511782e-01,  6.41977045e-01],
#        [-7.73713511e-01,  4.27594116e-01],
#        [-9.58129283e-01, -2.25274804e-01],
#        [-9.07834072e-01, -3.21936125e-01],
#        [-6.32077573e-01,  7.32158277e-01],
#        [-6.95091113e-01,  7.68878779e-01],
#        [-6.55779913e-01,  8.03979259e-01],
#        [-1.12346756e+00, -1.22673402e-01],
#        [-9.39051789e-01,  2.60191829e-01],
#        [-1.32407030e+00, -7.32341732e-01],
#        [-1.00784639e+00, -3.99157180e-01],
#        [-8.00884487e-01,  5.90136337e-01],
#        [-8.45398638e-01,  5.79876197e-01],
#        [-8.67944767e-01,  4.59454552e-01],
#        [-7.78338358e-01,  5.66376012e-01],
#        [-9.35583154e-01,  2.03491054e-01],
#        [-1.31077386e+00, -7.73382293e-01],
#        [-9.92815635e-01, -4.47217836e-01],
#        [-7.91056687e-01,  4.92935009e-01],
#        [-1.02808009e+00,  8.25294016e-02],
#        [-8.84709838e-01,  3.23912700e-01],
#        [-9.65644659e-01,  2.02951047e-01],
#        [-9.89925106e-01,  1.20869925e-01],
#        [-1.17029414e+00, -5.26598921e-01],
#        [-8.74882038e-01, -2.96015770e-01],
#        [-7.14168606e-01,  5.92836374e-01],
#        [-7.37870947e-01,  7.21898137e-01],
#        [-8.10134180e-01,  4.63774611e-01],
#        [-8.48867274e-01,  4.51354441e-01],
#        [-9.08412178e-01,  2.56951785e-01],
#        [-1.30383659e+00, -7.87422485e-01],
#        [-1.25585381e+00, -6.09760057e-01],
#        [-1.48940858e+00,  2.55871770e-01],
#        [-1.48940858e+00,  3.42812958e-01],
#        [-1.48940858e+00,  2.96372323e-01],
#        [-1.48940858e+00,  2.83952154e-01],
#        [-1.48940858e+00, -3.24096154e-01],
#        [-1.48940858e+00, -4.20217467e-01],
#        [-1.48940858e+00, -5.78979637e-01],
#        [-1.48940858e+00,  1.39770184e-01],
#        [-1.48940858e+00,  2.59651822e-01],
#        [-1.48940858e+00,  4.85089368e-02],
#        [-1.48940858e+00,  1.64070516e-01],
#        [-1.48940858e+00, -3.59196634e-01],
#        [-1.48940858e+00, -6.23800249e-01],
#        [-1.48940858e+00, -7.23161607e-01],
#        [-1.48940858e+00, -4.95818500e-01],
#        [-1.48940858e+00, -3.34896302e-01],
#        [-1.48940858e+00, -1.22133395e-01],
#        [-1.48940858e+00, -6.32980374e-01],
#        [-1.48940858e+00, -3.35436309e-01],
#        [-1.48940858e+00, -7.27481666e-01],
#        [-1.48940858e+00, -7.63662160e-01],
#        [-1.48940858e+00, -5.69259504e-01],
#        [-1.48940858e+00, -6.94541216e-01],
#        [-1.48940858e+00, -9.82365148e-01],
#        [-1.48940858e+00, -9.34304491e-01],
#        [-1.48940858e+00, -9.26204381e-01],
#        [-1.48940858e+00, -1.01692562e+00],
#        [-1.48940858e+00, -1.06930634e+00],
#        [-1.48940858e+00, -8.96503975e-01],
#        [-1.48940858e+00, -9.17024255e-01],
#        [-1.48940858e+00, -9.41324587e-01],
#        [-1.48940858e+00, -9.66164927e-01],
#        [-1.48940858e+00, -9.28904418e-01],
#        [-1.48940858e+00, -1.04284597e+00],
#        [-1.48940858e+00, -1.06282625e+00],
#        [-1.48940858e+00, -9.23504344e-01],
#        [-1.48940858e+00, -9.39704565e-01],
#        [-1.48940858e+00, -1.02016566e+00],
#        [-1.48940858e+00, -1.06066622e+00],
#        [-1.48940858e+00, -1.11088690e+00],
#        [-1.48940858e+00, -1.09846673e+00],
#        [-1.48940858e+00, -1.10224679e+00],
#        [-1.48940858e+00, -1.07686644e+00],
#        [-1.48940858e+00, -1.06822632e+00],
#        [-1.48940858e+00, -1.06822632e+00],
#        [-1.48940858e+00, -1.06984634e+00]])

# %%
df['Producto4Normalizado'] = df['Producto4']/np.max(df['Producto4'])

# %%
np.max(df['Producto4'])
# Out:
# 7575.0

# %%
df.head()
# Out:
#             Producto1  Producto2  Producto3    Producto4  Producto3sqrt  \
# Fecha
# 2009-01-01         29         20         35  2576.359551           35.0
# 2009-01-02         19          3         22  2576.359551           22.0
# 2009-01-03         24         12         22  2576.359551           22.0
# 2009-01-04         24          8         15  2576.359551           15.0
# 2009-01-05        120        111        141  2576.359551          141.0
#
#             Total  month  Producto4Normalizado
# Fecha
# 2009-01-01     84      1              0.340113
# 2009-01-02     44      1              0.340113
# 2009-01-03     58      1              0.340113
# 2009-01-04     47      1              0.340113
# 2009-01-05    372      1              0.340113

# %%
help(preprocessing.scale)

# %%
scaled.shape
# Out:
# (365, 2)

# %%
scaled.mean(axis=1)
# Out:
# array([-0.55571346, -0.5592235 , -0.5592235 , -0.56111353, -0.52709306,
#        -0.50144271, -0.54356329, -0.56138353, -0.55652347, -0.54383329,
#        -0.48254246, -0.51926296, -0.51872295, -0.51791294, -0.51872295,
#        -0.53897323, -0.55976351, -0.55031338, -0.51062284, -0.51764294,
#        -0.52817308, -0.50981283, -0.52385302, -0.56246355, -0.55760348,
#        -0.52844308, -0.50549277, -0.53465317, -0.53357315, -0.53654319,
#        -0.55976351, -0.56462358, -0.51818294, -0.52493304, -0.52493304,
#        -0.54572332, -0.51170285, -0.54545332, -0.54383329, -0.51386288,
#        -0.49496263, -0.48308246, -0.50279273, -0.50522277, -0.54221327,
#        -0.53789321, -0.48659251, -0.4712023 , -0.46499222, -0.51845295,
#        -0.52115298, -0.54545332, -0.54869336, -0.53357315, -0.53033311,
#        -0.52466303, -0.48065243, -0.52277301, -0.56057352, -0.54356329,
#        -0.54005324, -0.51197286, -0.52304301, -0.46310219, -0.51170285,
#        -0.51143285, -0.5006327 , -0.56516358, -0.46958228, -0.48686252,
#        -0.52034297, -0.51656292, -0.49091257, -0.45041202, -0.41558154,
#        -0.30407002, -0.42611168, -0.44231191, -0.40478139, -0.44528195,
#        -0.48254246, -0.50360274, -0.45851213, -0.48200245, -0.44798198,
#        -0.47228232, -0.52817308, -0.56516358, -0.56516358, -0.56516358,
#        -0.56516358, -0.44447194, -0.56516358, -0.56516358, -0.56516358,
#        -0.56516358, -0.56516358, -0.56516358, -0.56516358, -0.56516358,
#        -0.56516358, -0.56516358, -0.56516358, -0.56516358, -0.56516358,
#        -0.56516358, -0.17743829, -0.34214054, -0.18013832,  0.14926618,
#        -0.41072147, -0.04243644,  0.09715546,  0.17572654,  0.33097866,
#        -0.30758007,  0.49433089,  0.10390556,  0.23485735,  0.49271087,
#        -0.15988805, -0.18121834, -0.18148834,  0.49001083,  0.61394253,
#         0.06529503, -0.30434002,  0.09904549, -0.15907804, -0.42395166,
#         0.3852494 ,  0.4802907 ,  0.64607296,  0.09418542,  0.39631955,
#        -0.40397138, -0.34511058, -0.1123674 ,  0.16897645, -0.03136629,
#         0.89204633,  0.48488076,  0.34366883,  0.34420884,  0.50027097,
#         0.49730093, -0.09562717, -0.04999655, -0.22846898, -0.23359905,
#        -0.156108  ,  0.17086647,  0.44816026,  0.31477844,  0.7295041 ,
#         0.57506199,  0.29668819, -0.19228849,  0.44519022, -0.21091874,
#         0.50891109,  0.73139413,  0.43844013,  0.3412388 ,  0.27724793,
#         0.39010947,  0.94928711,  1.06754872,  0.11821575,  0.32827862,
#         0.18382665,  0.11821575,  0.79349498,  0.88907628,  0.2756279 ,
#         0.66092317,  0.51053111, -0.11830748,  0.16087634, -0.19795857,
#         0.64229291,  0.25861767,  0.65660311,  0.26347774,  0.06259499,
#         0.32854863,  0.58208209,  0.26320323,  1.05397921,  2.43249932,
#         2.2584389 , -0.11437789,  1.0087817 ,  0.97000478,  0.86067072,
#         2.19061086,  0.9456945 ,  1.59138663,  0.48376629,  0.61647885,
#         2.10686084,  2.15875622,  1.00961497,  1.76892067,  1.06462281,
#         0.85583376, -0.2303221 ,  1.31015386,  2.24481532,  1.2842335 ,
#         2.1730548 ,  1.29012719,  1.29136616, -0.45404331,  2.07990684,
#         1.42090917,  2.15276726,  1.37073736,  1.32699513,  1.14798181,
#         0.3548735 ,  0.76035851,  0.94993753,  2.12912123,  2.07025878,
#         1.73492836,  0.97524409,  0.73421037,  1.52677627,  1.57226112,
#         2.09727572,  1.15657395,  0.62949042,  0.92365685,  0.56537942,
#         1.52447794,  2.26470202,  1.8746594 ,  1.88972246,  1.59088806,
#        -0.55981184,  0.15818828,  1.74850393,  2.25244171,  2.21814377,
#         2.22995273,  1.81564376,  0.72575994,  0.61114008,  0.66430841,
#         2.36735065,  2.38721415,  2.35327156,  2.02883981,  1.24037694,
#         0.58429294,  1.28669343,  1.56457691,  1.57978409,  1.50226075,
#         0.33554186,  0.15001699,  0.19426528,  1.31157524,  0.21853421,
#         0.36907119,  1.21454954,  0.82805504,  0.20207055, -0.84079533,
#        -0.1416076 , -0.14488822,  0.25883268,  0.1017212 ,  0.2495308 ,
#        -0.73834053, -0.54987882,  0.228907  ,  0.57394517, -0.26267936,
#         0.37813454, -0.66299956, -0.63033246, -0.72822451, -0.7384888 ,
#        -0.46141366, -0.04034627, -0.04476737, -0.1730597 , -0.59170204,
#        -0.6148851 ,  0.05004035,  0.03689383,  0.07409967, -0.62307048,
#        -0.33942998, -1.02820601, -0.70350178, -0.10537407, -0.13276122,
#        -0.20424511, -0.10598117, -0.36604605, -1.04207808, -0.72001674,
#        -0.14906084, -0.47277535, -0.28039857, -0.38134681, -0.43452759,
#        -0.84844653, -0.5854489 , -0.06066612, -0.0079864 , -0.17317978,
#        -0.19875642, -0.3257302 , -1.04562954, -0.93280693, -0.6167684 ,
#        -0.57329781, -0.59651813, -0.60272821, -0.90675237, -0.95481302,
#        -1.03419411, -0.6748192 , -0.61487838, -0.72044982, -0.66266903,
#        -0.9243026 , -1.05660441, -1.10628509, -0.99261354, -0.91215244,
#        -0.80577099, -1.06119448, -0.91242244, -1.10844512, -1.12653537,
#        -1.02933404, -1.0919749 , -1.23588686, -1.21185653, -1.20780648,
#        -1.2531671 , -1.27935746, -1.19295628, -1.20321642, -1.21536658,
#        -1.22778675, -1.2091565 , -1.26612728, -1.27611741, -1.20645646,
#        -1.21455657, -1.25478712, -1.2750374 , -1.30014774, -1.29393766,
#        -1.29582768, -1.28313751, -1.27881745, -1.27881745, -1.27962746])

# %%
scaled.std(axis=1)
# Out:
# array([0.55571346, 0.5592235 , 0.5592235 , 0.56111353, 0.52709306,
#        0.50144271, 0.54356329, 0.56138353, 0.55652347, 0.54383329,
#        0.48254246, 0.51926296, 0.51872295, 0.51791294, 0.51872295,
#        0.53897323, 0.55976351, 0.55031338, 0.51062284, 0.51764294,
#        0.52817308, 0.50981283, 0.52385302, 0.56246355, 0.55760348,
#        0.52844308, 0.50549277, 0.53465317, 0.53357315, 0.53654319,
#        0.55976351, 0.56462358, 0.51818294, 0.52493304, 0.52493304,
#        0.54572332, 0.51170285, 0.54545332, 0.54383329, 0.51386288,
#        0.49496263, 0.48308246, 0.50279273, 0.50522277, 0.54221327,
#        0.53789321, 0.48659251, 0.4712023 , 0.46499222, 0.51845295,
#        0.52115298, 0.54545332, 0.54869336, 0.53357315, 0.53033311,
#        0.52466303, 0.48065243, 0.52277301, 0.56057352, 0.54356329,
#        0.54005324, 0.51197286, 0.52304301, 0.46310219, 0.51170285,
#        0.51143285, 0.5006327 , 0.56516358, 0.46958228, 0.48686252,
#        0.52034297, 0.51656292, 0.49091257, 0.45041202, 0.41558154,
#        0.30407002, 0.42611168, 0.44231191, 0.40478139, 0.44528195,
#        0.48254246, 0.50360274, 0.45851213, 0.48200245, 0.44798198,
#        0.47228232, 0.52817308, 0.56516358, 0.56516358, 0.56516358,
#        0.56516358, 0.44447194, 0.56516358, 0.56516358, 0.56516358,
#        0.56516358, 0.56516358, 0.56516358, 0.56516358, 0.56516358,
#        0.56516358, 0.56516358, 0.56516358, 0.56516358, 0.56516358,
#        0.56516358, 0.17743829, 0.34214054, 0.18013832, 0.14926618,
#        0.41072147, 0.04243644, 0.09715546, 0.17572654, 0.33097866,
#        0.30758007, 0.49433089, 0.10390556, 0.23485735, 0.49271087,
#        0.15988805, 0.18121834, 0.18148834, 0.49001083, 0.61394253,
#        0.06529503, 0.30434002, 0.09904549, 0.15907804, 0.42395166,
#        0.3852494 , 0.4802907 , 0.64607296, 0.09418542, 0.39631955,
#        0.40397138, 0.34511058, 0.1123674 , 0.16897645, 0.03136629,
#        0.89204633, 0.48488076, 0.34366883, 0.34420884, 0.50027097,
#        0.49730093, 0.09562717, 0.04999655, 0.22846898, 0.23359905,
#        0.156108  , 0.17086647, 0.44816026, 0.31477844, 0.7295041 ,
#        0.57506199, 0.29668819, 0.19228849, 0.44519022, 0.21091874,
#        0.50891109, 0.73139413, 0.43844013, 0.3412388 , 0.27724793,
#        0.39010947, 0.94928711, 1.06754872, 0.11821575, 0.32827862,
#        0.18382665, 0.11821575, 0.79349498, 0.88907628, 0.2756279 ,
#        0.66092317, 0.51053111, 0.11830748, 0.16087634, 0.19795857,
#        0.64229291, 0.25861767, 0.65660311, 0.26347774, 0.06259499,
#        0.32854863, 0.58208209, 0.50621555, 0.08583771, 0.45724406,
#        0.45382597, 0.03382507, 0.43916564, 0.01055689, 0.17929176,
#        0.33145719, 0.03803383, 0.3872619 , 0.09991278, 0.28284602,
#        0.48747044, 0.39626386, 0.00475297, 0.28777216, 0.12780174,
#        0.33427836, 0.01962749, 0.11466925, 0.43912237, 0.1405896 ,
#        0.50452373, 0.24800467, 0.61212861, 0.02194568, 0.5895782 ,
#        0.20220425, 0.47451606, 0.18011282, 0.13367055, 0.55028537,
#        0.19296301, 0.17076218, 0.08061738, 0.50163072, 0.47030865,
#        0.34720112, 0.47096893, 0.32929657, 0.26919081, 0.20289414,
#        0.4028243 , 0.18789244, 0.05015423, 0.37456107, 0.26630706,
#        0.18535137, 0.31806715, 0.24446885, 0.22767148, 0.19236068,
#        0.09423375, 0.12371953, 0.19661446, 0.26962634, 0.36925024,
#        0.24875738, 0.06935162, 0.20420454, 0.23268663, 0.37549619,
#        0.05297076, 0.01140689, 0.07342987, 0.02417651, 0.27925553,
#        0.21501962, 0.31163668, 0.52245988, 0.60877409, 0.68791744,
#        0.5710388 , 0.1652556 , 0.17770807, 0.7203808 , 0.5962452 ,
#        0.67683137, 0.86384713, 0.75137482, 0.21904348, 0.2693758 ,
#        0.52978117, 0.56870228, 0.7082288 , 0.67309766, 0.63706959,
#        0.34350341, 0.2943636 , 0.69333387, 0.78516167, 0.65787304,
#        0.73040888, 0.44312483, 0.27923593, 0.28424672, 0.21674995,
#        0.52504281, 0.65532295, 0.68674441, 0.60065381, 0.36642724,
#        0.29294897, 0.68211793, 0.73198495, 0.72987959, 0.50039708,
#        0.59962181, 0.29586428, 0.3043446 , 0.69551041, 0.71263742,
#        0.66369966, 0.67235719, 0.5695371 , 0.26869579, 0.2727989 ,
#        0.64199585, 0.55530475, 0.60431127, 0.58429785, 0.55539752,
#        0.32184761, 0.28943313, 0.65350249, 0.72988454, 0.6369544 ,
#        0.65011086, 0.58268198, 0.25820705, 0.32304687, 0.87264017,
#        0.91611077, 0.89289045, 0.88668036, 0.58265621, 0.53459555,
#        0.45521447, 0.81458938, 0.8745302 , 0.76895876, 0.82673955,
#        0.56510597, 0.43280416, 0.38312348, 0.49679504, 0.57725614,
#        0.68363759, 0.4282141 , 0.57698613, 0.38096346, 0.36287321,
#        0.46007454, 0.39743368, 0.25352171, 0.27755204, 0.2816021 ,
#        0.23624148, 0.21005112, 0.2964523 , 0.28619216, 0.27404199,
#        0.26162182, 0.28025208, 0.2232813 , 0.21329116, 0.28295212,
#        0.27485201, 0.23462146, 0.21437118, 0.18926084, 0.19547092,
#        0.1935809 , 0.20627107, 0.21059113, 0.21059113, 0.20978112])

# %% [markdown]
# <p><a name="bineado"></a></p>
#
# ## 2.9. Bineado de datos
# La función `cut` nos permite separar los datos en bloques (bins)

# %%
df.Producto1[:10]
# Out:
# Fecha
# 2009-01-01     29
# 2009-01-02     19
# 2009-01-03     24
# 2009-01-04     24
# 2009-01-05    120
# 2009-01-06    261
# 2009-01-07     60
# 2009-01-08     24
# 2009-01-09     35
# 2009-01-10     81
# Name: Producto1, dtype: int64

# %% [markdown]
# Se puede seleccionar el número de bins deseado y el programa obtiene la distribución óptima de los mismos

# %%
pd.cut(df.Producto1[:], bins=3)
# Out:
# Fecha
# 2009-01-01    (-6.626, 2208.667]
# 2009-01-02    (-6.626, 2208.667]
# 2009-01-03    (-6.626, 2208.667]
# 2009-01-04    (-6.626, 2208.667]
# 2009-01-05    (-6.626, 2208.667]
#                      ...
# 2009-12-27    (-6.626, 2208.667]
# 2009-12-28    (-6.626, 2208.667]
# 2009-12-29    (-6.626, 2208.667]
# 2009-12-30    (-6.626, 2208.667]
# 2009-12-31    (-6.626, 2208.667]
# Name: Producto1, Length: 365, dtype: category
# Categories (3, interval[float64, right]): [(-6.626, 2208.667] < (2208.667, 4417.333] <
#                                            (4417.333, 6626.0]]

# %% [markdown]
# Se puede seleccionar los intervalos de los bins deseados

# %%
h=pd.cut(df.Producto1[:],bins=[0,100,200,700])

# %%
print(h)
# Out:
# Fecha
# 2009-01-01      (0, 100]
# 2009-01-02      (0, 100]
# 2009-01-03      (0, 100]
# 2009-01-04      (0, 100]
# 2009-01-05    (100, 200]
#                  ...
# 2009-12-27      (0, 100]
# 2009-12-28      (0, 100]
# 2009-12-29      (0, 100]
# 2009-12-30      (0, 100]
# 2009-12-31      (0, 100]
# Name: Producto1, Length: 365, dtype: category
# Categories (3, interval[int64, right]): [(0, 100] < (100, 200] < (200, 700]]

# %%
help(pd.cut)

# %% [markdown]
# Se pueden poner etiquetas sobre los bins

# %%
y= pd.cut(df.Producto1[:],bins=3, labels=['bajo','medio','alto'])

# %%
y = pd.DataFrame(y)

# %%
y
# Out:
#            Producto1
# Fecha
# 2009-01-01      bajo
# 2009-01-02      bajo
# 2009-01-03      bajo
# 2009-01-04      bajo
# 2009-01-05      bajo
# ...              ...
# 2009-12-27      bajo
# 2009-12-28      bajo
# 2009-12-29      bajo
# 2009-12-30      bajo
# 2009-12-31      bajo
#
# [365 rows x 1 columns]

# %%
y.groupby('Producto1')['Producto1'].count().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Producto1'>

# %% [markdown]
# <p><a name="concom"></a></p>
#
# ## 2.10. Concatenación y combinación de dataframes
#
# La concatenación se realiza mediante la función `concat()` y la combinación mediante la función `merge()`

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

# %%
data1
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
data2
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
# Concatenar por filas
all_data = pd.concat([data1, data2])
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
# Concatenar por columnas
all_data_col = pd.concat([data1, data2], axis = 1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
# Combinar all_data y data3 a lo largo del valor de subject_id
pd.merge(all_data, data3, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
# Combinar solo los datos que tienen el mismo 'subject_id' en data1 y data2 (interseccion)
pd.merge(data1, data2, on='subject_id', how='inner')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
# Combinar solo los datos que tienen el mismo 'subject_id' en data1 y data2 (union)
pd.merge(data1, data2, on=['subject_id',], how='outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %%
help(pd.merge)

# %%
set()

# %% [markdown]
# <p><a name="tallpan"></a></p>
#
# ## 3. Taller Pandas

# %% [markdown]
# ### Ejercicio 1
#
# Cargue el dataset provisto en la dirección 'https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv'  grafique la ganancia total (total_profit) para todos los meses. La gráfica debe tener las siguientes propiedades:
#
# * El estilo de línea punteado y de color rojo
# * Mostrar la legenda (legend) en la parte inferior derecha
# * X label name = Month Number
# * Y label name = Profits in dollars
# * Título : Company sales data of last year
# * Los markers deben ser circulares y de color negro
# * El grosor de la línea debe ser 3
#
# Solución esperada:
# <p><img  height="260px" src="https://pynative.com/wp-content/uploads/2019/01/matplotlib_and_pandas_exercise_2_plot_style_properties-768x512.png" align="center" hspace="10px" vspace="0px"></p>

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
# import pandas as pd
# import matplotlib.pyplot as plt
# df = pd.read_csv('https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv')
# profitList = df ['total_profit'].tolist()
# monthList  = df ['month_number'].tolist()
# plt.plot(monthList, profitList, label = 'Profit data of last year',
#       color='r', marker='o', markerfacecolor='k',
#       linestyle='--', linewidth=3)
#
# plt.xlabel('Month Number')
# plt.ylabel('Profit in dollar')
# plt.legend(loc='lower right')
# plt.title('Company Sales data of last year')
# plt.xticks(monthList)
# plt.yticks([100000, 200000, 300000, 400000, 500000])
# plt.show()
# -->

# %%
import pandas as pd
import matplotlib.pyplot as plt  
df = pd.read_csv('https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv')
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
plt.plot(monthList, profitList, label = 'Profit data of last year', 
      color='r', marker='o', markerfacecolor='k', 
      linestyle='--', linewidth=3)
      
plt.xlabel('Month Number')
plt.ylabel('Profit in dollar')
plt.legend(loc='lower right')
plt.title('Company Sales data of last year')
plt.xticks(monthList)
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %% [markdown]
# ### Ejercicio 2
#
# Dataset: https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
#
# 1. Importar el dataset, asignarlo a una variable llamada *users* y usar el *user_id* como índice.
# 2. ¿Cuál es el número de observaciones y columnas en el dataset?
# 3. Mostrar el nombre de las columnas y el tipo de dato que contiene.
# 4. Mostrar la indexación del dataset.
# 5. ¿Cuántas ocupaciones diferentes hay en este conjunto de datos?
# 6. ¿Cuál es la ocupación más frecuente?
# 7. ¿Cuál es la edad media de los usuarios?
# 8. ¿Cuál es la edad con menos ocurrencia?

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
# 1.
#
# import pandas as pd
#
# users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', delimiter='|', index_col='user_id')
# users.head()
#
# 2.
# print("Número de observaciones:",users.shape[0])
# print("Número de columnas: ",users.shape[1])
#
# 3.
# print("Columnas: ",users.columns)
# print("Tipo de datos: \n",users.dtypes)
#
# 4.
# print("Indexación: ",users.index)
#
# 5.
# print("Número de ocupaciones diferentes:",users.occupation.nunique())
#
# 6.
# print("Ocupaciones más frecuentes:\n",users.occupation.value_counts().head())
#
# 7.
# print("Edad media de los usuarios:",round(users.age.mean()))
#
# 8.
# print("Edades de menos ocurrencia:\n",users.age.value_counts().tail(10))
#
# -->

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# Diccionario dado:
#
# raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
#             'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
#             'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
#             'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
#             'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
#             'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
#             'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
#             'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
#             'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
#             'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}
#
# 1. Crea un DataFrame llamado *army* a partir del diccionario dado
#
# (No olvide incluir los nombres de las columnas en el orden presentado en el diccionario ('regimen', 'company', ...) para que el orden del índice de la columna sea coherente con las soluciones. Si se omite, Pandas ordenará las columnas alfabéticamente.
#
# 2. Establezca la columna 'origin' como índice del dataset.
# 3. Imprima las columnas 'veterans' y 'deaths'
# 4. Seleccione las columnas 'deaths', 'size' y 'deserters' de Maine a Alaska.
# 5. Seleccione la tercera columna hasta la séptima columna.
# 6. Seleccione las filas donde *deaths* sea mayor que 50.
# 7. Seleccione las filas donde *deaths* sea mayor que 500 o menor que 50.
# 8. Selecciona todos los *regiments* no nombrados *Dragoons*.
# 9. Seleccione la tercera celda en la fila llamada *Arizona*
# 10. Seleccione la tercera celda en la columna llamada *deaths*

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
# 1.
# raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'], 'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'], 'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35], 'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9], 'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523], 'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345], 'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3], 'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1], 'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3], 'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}
#
# army = pd.DataFrame(raw_data, columns = ['regiment', 'company', 'deaths', 'battles', 'size', 'veterans', 'readiness', 'armored', 'deserters', 'origin'])
#
# army.head()
#
# 2.
# army = army.set_index("origin")
# army.head()
#
# 3.
# army[['veterans', 'deaths']]
#
# 4.
# army.loc[['Maine','Alaska'] , ["deaths","size","deserters"]]
#
# 5.
# army.iloc[: , 4:7]
#
# 6.
# army[army['deaths'] > 50]
#
# 7.
# army[(army['deaths'] > 500) | (army['deaths'] < 50)]
#
# 8.
# army[(army['regiment'] != 'Dragoons')]
#
# 9.
# army.loc[['Arizona'], ['deaths']]
#
# #O
#
# #army.iloc[[0]
#
# 10.
# army.loc['Texas', 'deaths']
#
# #O
#
# #army.iloc[[2]
#
#
# -->

# %% [markdown]
# ### Ejercicio 4
#
# Dataset: https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
#
# 1.  Importar el dataset, asignarlo a una variable llamada *users* y usar el *user_id* como índice.
# 2. ¿Cuál es la edad media por ocupación?
# 3. Descubra la proporción de hombres por ocupación y clasifíquela de mayor a menor (cree una columna).
# 4. Para cada ocupación calcule las edades mínimas y máximas.
# 5. Para cada combinación de ocupación y género calcule la edad media.
# 6. Para cada ocupación muestre el porcentaje de mujeres y hombres.

# %% [markdown]
# Para ver la solución haga double-click <b>aquí</b>.
# <!--
#
# 1.
#
# import pandas as pd
#
# users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', delimiter='|', index_col='user_id')
# users.head()
#
# 2.
# users.groupby('occupation').age.mean()
#
# 3.
# # funcion que mapea el genero a un numero
# def gender_to_numeric(x):
#     if x == 'M':
#         return 1
#     if x == 'F':
#         return 0
#
# # aplica la funcion a la columna genero y saca el porcentaje de hombres por ocupacion
# users['gender_n'] = users['gender'].apply(gender_to_numeric)
#
# # se
# a = users.groupby('occupation').gender_n.sum() / users.occupation.value_counts() * 100
#
# # ordenamiento de mayor a menor
# a.sort_values(ascending = False)
#
# 4.
# users.groupby('occupation').age.agg(['min', 'max'])
#
# 5.
# users.groupby(['occupation', 'gender']).age.mean()
#
# 6.
# # crea un dataframe y aplica "count" al genero
# gender_ocup = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})
#
# # crea un dataframe y aplica "count" para cada ocupacion
# occup_count = users.groupby(['occupation']).agg('count')
#
# # divida gender_ocup por occup_count y multiplique por 100
# occup_gender = gender_ocup.div(occup_count, level = "occupation") * 100
#
# # mostrar todas las filas de la columna genero
# occup_gender.loc[: , 'gender']
#
# -->
