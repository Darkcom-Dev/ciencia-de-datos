# %% [markdown]
# Joyce Kuhiman es gerente de un centro financiero regional y desea comparar la productividad,
# medida por el numero de clientes atendidos, de tres empleados. Selecciona cuatro dias en
# forma aleatoria y registra el némero de clientes que atendié cada empleado. Los resultados son:
#
# <table>
# <tr>
# <th>Wolfe</th><th>White</th><th>Korosa</th>
# <tr>
# <td>55</td><td>66</td><td>47</td>
# <tr>
# <td>54</td><td>76</td><td>51</td>
# <tr>
# <td>59</td><td>67</td><td>46</td>
# <tr>
# <td>56</td><td>71</td><td>48</td>
# </table>
#
#
#
# ¿Hay alguna diferencia en el nimero medio de clientes atendidos? En la grafica 12-1 se ilustra
# cémo pueden aparecer las poblaciones si hubiera una diferencia en las medias del tratamien-
# to. Observe que las poblaciones siguen la distribucién normal y la variacién en cada poblacién
# es la misma. Sin embargo, las medias no son iguales.

# %% [markdown]
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <svg
#    xmlns:dc="http://purl.org/dc/elements/1.1/"
#    xmlns:cc="http://creativecommons.org/ns#"
#    xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#    xmlns:svg="http://www.w3.org/2000/svg"
#    xmlns="http://www.w3.org/2000/svg"
#    xmlns:sodipodi="http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd"
#    xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
#    version="1.1"
#    id="svg2"
#    width="120.7135"
#    height="88.217194"
#    viewBox="0 0 120.7135 88.217194"
#    sodipodi:docname="1a.svg"
#    inkscape:version="1.0.2 (e86c870879, 2021-01-15)">
#   <metadata
#      id="metadata8">
#     <rdf:RDF>
#       <cc:Work
#          rdf:about="">
#         <dc:format>image/svg+xml</dc:format>
#         <dc:type
#            rdf:resource="http://purl.org/dc/dcmitype/StillImage" />
#         <dc:title></dc:title>
#       </cc:Work>
#     </rdf:RDF>
#   </metadata>
#   <defs
#      id="defs6" />
#   <sodipodi:namedview
#      pagecolor="#ffffff"
#      bordercolor="#666666"
#      borderopacity="1"
#      objecttolerance="10"
#      gridtolerance="10"
#      guidetolerance="10"
#      inkscape:pageopacity="0"
#      inkscape:pageshadow="2"
#      inkscape:window-width="1366"
#      inkscape:window-height="719"
#      id="namedview4"
#      showgrid="false"
#      inkscape:zoom="2.2960735"
#      inkscape:cx="48.078344"
#      inkscape:cy="84.108631"
#      inkscape:window-x="0"
#      inkscape:window-y="0"
#      inkscape:window-maximized="1"
#      inkscape:current-layer="g10" />
#   <g
#      inkscape:groupmode="layer"
#      inkscape:label="Image"
#      id="g10"
#      transform="translate(-14.960306,-7.5586302)">
#     <path
#        style="fill:none;stroke:#696969;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="M 42.694825,7.733174 15.680134,80.251378 H 129.57785"
#        id="path837" />
#     <path
#        style="fill:none;stroke:#696969;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="M 40.041037,80.017878 52.47745,47.813035"
#        id="path839" />
#     <path
#        style="fill:none;stroke:#696969;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="M 73.715409,79.927511 93.62161,27.032073"
#        id="path841" />
#     <path
#        style="fill:none;stroke:#696969;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="m 99.252508,80.705519 4.110182,-9.593816"
#        id="path843" />
#     <path
#        style="fill:#ff00ff;stroke:#228822;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="m 30.82617,45.455588 6.8386,-0.435526 c 0,0 11.632374,-5.980836 15.468508,-5.980836 3.836133,0 9.545861,5.23811 14.423885,5.679982 4.878024,0.441873 6.947249,0.877399 6.947249,0.877399 l -0.03149,2.149613 -43.568236,0.06034 z"
#        id="path853"
#        sodipodi:nodetypes="ccsscccc" />
#     <path
#        style="fill:#ff00ff;stroke:#228822;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="m 72.667056,24.31687 6.8386,-0.435526 c 0,0 11.632374,-5.980836 15.468508,-5.980836 3.836133,0 9.545856,5.23811 14.423886,5.679982 4.87802,0.441873 6.94725,0.877399 6.94725,0.877399 l -0.0315,2.149613 -43.568238,0.06034 z"
#        id="path855"
#        sodipodi:nodetypes="ccsscccc" />
#     <path
#        style="fill:#ff00ff;stroke:#228822;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="m 81.780116,68.137287 6.8386,-0.435526 c 0,0 11.632374,-5.980836 15.468504,-5.980836 3.83614,0 9.54586,5.23811 14.42389,5.679982 4.87802,0.441873 6.94725,0.877399 6.94725,0.877399 l -0.0315,2.149613 -43.568238,0.06034 z"
#        id="path857"
#        sodipodi:nodetypes="ccsscccc" />
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#808080;fill-opacity:1;stroke:none"
#        x="115.2538"
#        y="19.426493"
#        id="text861"><tspan
#          sodipodi:role="line"
#          id="tspan859"
#          x="115.2538"
#          y="19.426493"
#          style="font-size:5.33333px;fill:#808080">Wolfe</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#808080;fill-opacity:1;stroke:none"
#        x="120.44986"
#        y="64.866837"
#        id="text865"><tspan
#          sodipodi:role="line"
#          id="tspan863"
#          x="120.44986"
#          y="64.866837"
#          style="font-size:5.33333px;fill:#808080">White</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#808080;fill-opacity:1;stroke:none"
#        x="67.640533"
#        y="41.700298"
#        id="text869"><tspan
#          sodipodi:role="line"
#          id="tspan867"
#          x="67.640533"
#          y="41.700298"
#          style="font-size:5.33333px;fill:#808080">Korosa</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#a9a9a9;fill-opacity:1;stroke:none"
#        x="94.864975"
#        y="87.578438"
#        id="text873"><tspan
#          sodipodi:role="line"
#          id="tspan871"
#          x="94.864975"
#          y="87.578438"
#          style="font-size:5.33333px;fill:#a9a9a9">U3</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#808080;fill-opacity:1;stroke:none"
#        x="50.438316"
#        y="95.700302"
#        id="text877"><tspan
#          sodipodi:role="line"
#          x="50.438316"
#          y="95.700302"
#          style="font-size:5.33333px;fill:#808080"
#          id="tspan879">Clientes Atendidos</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#a9a9a9;fill-opacity:1;stroke:none"
#        x="-45.658619"
#        y="28.570604"
#        id="text885"
#        transform="rotate(-90)"><tspan
#          id="tspan883"
#          x="-45.658619"
#          y="28.570604"
#          style="font-size:5.33333px;fill:#a9a9a9"
#          sodipodi:role="line">Empleado</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#a9a9a9;fill-opacity:1;stroke:none"
#        x="67.341812"
#        y="86.887505"
#        id="text889"><tspan
#          sodipodi:role="line"
#          id="tspan887"
#          x="67.341812"
#          y="86.887505"
#          style="font-size:5.33333px;fill:#a9a9a9">U2</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#a9a9a9;fill-opacity:1;stroke:none"
#        x="33.173225"
#        y="87.180534"
#        id="text893"><tspan
#          sodipodi:role="line"
#          id="tspan891"
#          x="33.173225"
#          y="87.180534"
#          style="font-size:5.33333px;fill:#a9a9a9">U1</tspan></text>
#   </g>
# </svg>

# %% [markdown]
# > GRAFICA 12-1 Caso en el que las medias del tratamiento son diferentes

# %% [markdown]
# ## CAPITULO 12 Analisis de la varianza
#
# Suponga que las poblaciones son iguales. Es decir, que no hay una diferencia entre las
# medias (tratamiento). Esta igualdad, que se muestra en la grafica 12-2, indica que las medias poblacionales son iguales. Observe de nuevo que las poblaciones siguen la distribucién normal, y que la variacién en cada una de las poblaciones es la misma.

# %% [markdown]
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <svg
#    xmlns:dc="http://purl.org/dc/elements/1.1/"
#    xmlns:cc="http://creativecommons.org/ns#"
#    xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#    xmlns:svg="http://www.w3.org/2000/svg"
#    xmlns="http://www.w3.org/2000/svg"
#    version="1.1"
#    id="svg2"
#    width="120.7135"
#    height="88.217194"
#    viewBox="0 0 120.7135 88.217194">
#   <metadata
#      id="metadata8">
#     <rdf:RDF>
#       <cc:Work
#          rdf:about="">
#         <dc:format>image/svg+xml</dc:format>
#         <dc:type
#            rdf:resource="http://purl.org/dc/dcmitype/StillImage" />
#         <dc:title></dc:title>
#       </cc:Work>
#     </rdf:RDF>
#   </metadata>
#   <defs
#      id="defs6" />
#   <g
#      id="g10"
#      transform="translate(-14.960306,-7.5586302)">
#     <path
#        style="fill:none;stroke:#696969;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="M 42.694825,7.733174 15.680134,80.251378 H 129.57785"
#        id="path837" />
#     <path
#        style="fill:none;stroke:#696969;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="M 53.715409,79.927511 73.62161,27.032073"
#        id="path841" />
#     <path
#        style="fill:#ff00ff;stroke:#228822;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="m 44.794099,45.455588 6.8386,-0.435526 c 0,0 11.632374,-5.980836 15.468508,-5.980836 3.836133,0 9.545861,5.23811 14.423883,5.679982 4.87803,0.441873 6.94725,0.877399 6.94725,0.877399 l -0.0315,2.149613 -43.568235,0.06034 z"
#        id="path853" />
#     <path
#        style="fill:#ff00ff;stroke:#228822;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="m 52.667056,24.31687 6.8386,-0.435526 c 0,0 11.632374,-5.980836 15.468508,-5.980836 3.836133,0 9.545856,5.23811 14.423886,5.679982 4.87802,0.441873 6.94725,0.877399 6.94725,0.877399 l -0.0315,2.149613 -43.568238,0.06034 z"
#        id="path855" />
#     <path
#        style="fill:#ff00ff;stroke:#228822;stroke-width:1px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"
#        d="m 36.543009,68.142967 6.8386,-0.435526 c 0,0 11.632374,-5.980836 15.468504,-5.980836 3.83614,0 9.54586,5.23811 14.42389,5.679982 4.87802,0.441873 6.947247,0.877399 6.947247,0.877399 l -0.0315,2.149613 -43.568235,0.06034 z"
#        id="path857" />
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#808080;fill-opacity:1;stroke:none"
#        x="89.373749"
#        y="19.426493"
#        id="text861"><tspan
#          id="tspan859"
#          x="89.373749"
#          y="19.426493"
#          style="font-size:5.33333px;fill:#808080">Wolfe</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#808080;fill-opacity:1;stroke:none"
#        x="71.416611"
#        y="64.866837"
#        id="text865"><tspan
#          id="tspan863"
#          x="71.416611"
#          y="64.866837"
#          style="font-size:5.33333px;fill:#808080">White</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#808080;fill-opacity:1;stroke:none"
#        x="79.077271"
#        y="41.700298"
#        id="text869"><tspan
#          id="tspan867"
#          x="79.077271"
#          y="41.700298"
#          style="font-size:5.33333px;fill:#808080">Korosa</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#808080;fill-opacity:1;stroke:none"
#        x="50.438316"
#        y="95.700302"
#        id="text877"><tspan
#          x="50.438316"
#          y="95.700302"
#          style="font-size:5.33333px;fill:#808080"
#          id="tspan879">Clientes Atendidos</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#a9a9a9;fill-opacity:1;stroke:none"
#        x="-45.658619"
#        y="28.570604"
#        id="text885"
#        transform="rotate(-90)"><tspan
#          id="tspan883"
#          x="-45.658619"
#          y="28.570604"
#          style="font-size:5.33333px;fill:#a9a9a9">Empleado</tspan></text>
#     <text
#        xml:space="preserve"
#        style="font-style:normal;font-weight:normal;font-size:40px;line-height:1.25;font-family:sans-serif;fill:#a9a9a9;fill-opacity:1;stroke:none"
#        x="33.765907"
#        y="86.887505"
#        id="text889"><tspan
#          id="tspan887"
#          x="33.765907"
#          y="86.887505"
#          style="font-size:5.33333px;fill:#a9a9a9">U1 = U2 = U3</tspan></text>
#   </g>
# </svg>

# %% [markdown]
# > GRAFICA 12-2 Caso en el que las medias del tratamiento son iguales

# %% [markdown]
# > El uso de la distribucion $t$ conduce a la acumulacion del error tipo I.
#
# > OA3 Describir el enfoque ANOVA para probar
# diferencias entre medias muestrales.
#
# # Suposiciones en el analisis de la varianza (ANOVA)
#
# Otro uso de la distribucion $F$ es el analisis de la técnica de la varianza (ANOVA), en la cual se comparan tres o mas medias poblacionales para determinar si pueden ser iguales. Para emplear ANOVA, se supone lo siguiente:
#
# 1. Las poblaciones siguen la distribucién normal.
# 2. Las poblaciones tienen desviaciones estandares iguales (o).
# 3. Las poblaciones son independientes.
#
# Cuando se cumplen estas condiciones, $F$ se emplea como la distribucién del estadistico de prueba.
#
# ¿Por qué es necesario estudiar ANOVA? ¿Por qué no solo se emplea la prueba de las dife-
# rencias entre medias poblacionales, como se analizo en el capitulo anterior?
#
# Se puede comparar dos medias poblacionales a la vez. La razon mas importante es la acumulacion indeseable del error tipo |.
#
# Para ampliar la explicacion, suponga cuatro métodos distintos (A, B, C y D) para capacitar personal para ser bomberos. La asignacion de cada uno de los 40 prospectos del grupo de este año es aleatoria en cada uno de los cuatro métodos.
#
# Al final del programa de capacitacion, a los cuatro grupos se les administra una prueba comun para medir la comprension de las técnicas contra incendios.
#
# La pregunta es: ¿existe una diferencia entre las calificaciones medias del examen de los cuatro grupos?
#
# La respuesta a esta pregunta permitira comparar los cuatro métodos de capacitación.
#
# Si emplea la distribucién $t$ para comparar las cuatro medias poblacionales, tendria que
# efectuar seis pruebas t distintas.
#
# Es decir, necesitaria comparar las calificaciones medias de los cuatro métodos como sigue: $A$ contra $B$, $A$ contra $C$, $A$ contra $D$, $B$ contra $C$, $B$ contra $D$ y $C$ contra $D$.
#
# Si el nivel de significancia es de 0.05, la probabilidad de una decision estadistica correcta es de 0.95, calculada de 1 —- 0.05. Como se realizaron seis pruebas separadas (independientes), la probabilidad de que no se tome una decision incorrecta debido al error de muestreo en cualquiera de las seis pruebas independientes es:
#
# $$P(todas correctas) = (0.95)(0.95)(0.95)(0.95)(0.95)(0.95) = 0.735$$
#
# Para encontrar la probabilidad de que al menos tenga un error debido al muestreo, reste este resultado a 1. Por lo tanto, la probabilidad de al menos una decisién incorrecta debida al muestreo es de $1 - 0.735 = 0.265$.
#
# En resumen, si realiza seis pruebas independientes con la distribucion $t$, la posibilidad de rechazar una hipotesis nula verdadera debido al error de muestreo se incrementa de 0.05 a un nivel insatisfactorio de 0.265.
#
# Es obvio que necesita un mejormétodo que realizar seis pruebas t. ANOVA le permite comparar las medias de tratamiento de forma simultanea y evitar la acumulaci6n del error de tipo I.
#
# ANOVA se desarrollo para aplicaciones en agricultura, y alin se emplean muchos de los términos relacionados con ese contexto. En particular, con el término tratamiento se identi can las diferentes poblaciones que se examinan.
#
# Por ejemplo, el tratamiento se refiere a como se trato una extension de terreno con un tipo particular de fertilizante.
#
# La siguiente ilustracion aclarara el término tratamiento y mostrara la aplicacion de ANOVA.

# %% [markdown]
# Se localiza 0.4950 en el cuerpo de la tabla. El valor mas cercano a 0.4950 es 0.4951. En seguida se lee el valor critico en el renglén y columna correspondientes a 0.4951.
# Este es de 2.58. Por conveniencia, se repite el apéndice B.1, Areas bajo la curva normal, en la tercera de forros.
#
# Todas las facetas de este problema aparecen en el diagrama de la grafica 10-4.

# %% [markdown]
# <img src='3a.jpeg'>

# %% [markdown]
# > GRAFICA 10-4 Regla de decision del nivel de significancia de 0.01
#
# Por lo tanto, la regla de decisién es: rechazar la hipdtesis nula y aceptar la hipdtesis alternativa (que indica que la media de la poblaci6n no es 200) si el valor zZ calculado no se encuentra entre —2.58 y +2.58. La hipotesis nula no se rechaZa siz se ubica entre —2.58 y +2.58.
#
# Paso 5: Se toma una decision y se interpreta el resultado. Se toma una muestra de la poblaci6n (produccién semanal), se calcula z, se aplica la regla de decision y se llega a la decisi6n de rechazar 0 no Ho. La cantidad media de escritorios que se produjeron el afio pasado (50 semanas, pues la planta cerré 2 semanas por
# vacaciones) es de 203.5. La desviacion estandar de la poblacion es de 16 escritorios semanales.
#
# Al calcular el valor z a partir de la formula (10-1), se obtiene:
#
# $$ _ X= 203.5 — 200 2 olNn 16/50$$
#
# Como 1.55 no cae en la regidn de rechazo, Hy no se rechaza. La conclusiónes: la media de la poblaci6n no es distinta de 200. Por lo tanto, se informa al vicepresidente de fabricacién que la evidencia de la muestra no indica que la tasa de produccién en la planta de Fredonia haya cambiado de 200 semanales.
#
# La diferencia de 3.5 unidades entre la produccién semanal historica y la del afio pasado puede atribuirse razonablemente al error de muestreo. Esta informacion se resume en el siguiente diagrama:

# %% [markdown]
# <img src='3b.jpeg'>
